# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('mtcars.csv')

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.shape # dimension
# Out:
# (32, 12)

# %%
df['hp'].dtypes #finding types for perticular column
# Out:
# dtype('int64')

# %%
df.dtypes #give the datatypes of all the columns
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
df.describe # to describe the dataset
# Out:
# <bound method NDFrame.describe of                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#slicing

df[3:6]
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
#
#    carb
# 3     1
# 4     2
# 5     1

# %%
df.nunique()
# Out:
# model    32
# mpg      25
# cyl       3
# disp     27
# hp       22
# drat     22
# wt       29
# qsec     30
# vs        2
# am        2
# gear      3
# carb      6
# dtype: int64

# %%
df.nunique()
# Out:
# model    32
# mpg      25
# cyl       3
# disp     27
# hp       22
# drat     22
# wt       29
# qsec     30
# vs        2
# am        2
# gear      3
# carb      6
# dtype: int64

# %%
df.isnull()
# Out:
#     model    mpg    cyl   disp     hp   drat     wt   qsec     vs     am  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.mean()
# Out:
# C:\Users\LC\AppData\Local\Temp/ipykernel_7180/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df.mode()
# Out:
#                   model   mpg  cyl   disp     hp  drat    wt   qsec   vs   am  \
# 0           AMC Javelin  10.4  8.0  275.8  110.0  3.07  3.44  17.02  0.0  0.0
# 1    Cadillac Fleetwood  15.2  NaN    NaN  175.0  3.92   NaN  18.90  NaN  NaN
# 2            Camaro Z28  19.2  NaN    NaN  180.0   NaN   NaN    NaN  NaN  NaN
# 3     Chrysler Imperial  21.0  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 4            Datsun 710  21.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 5      Dodge Challenger  22.8  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 6            Duster 360  30.4  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 7          Ferrari Dino   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 8              Fiat 128   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 9             Fiat X1-9   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# 10       Ford Pantera L   NaN  NaN    NaN    NaN   NaN   NaN    NaN  NaN  NaN
# ...

# %%
df.median()
# Out:
# C:\Users\LC\AppData\Local\Temp/ipykernel_7180/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %% [markdown]
# Another lession

# %%
import pandas as pd #import libarries

# %%
dff = pd.read_csv("middle_tn_schools.csv")  #import dataset

# %%
dff.describe()
# Out:
#        school_rating         size  reduced_lunch  state_percentile_16  \
# count     347.000000   347.000000     347.000000           347.000000
# mean        2.968300   699.472622      50.279539            58.801729
# std         1.690377   400.598636      25.480236            32.540747
# min         0.000000    53.000000       2.000000             0.200000
# 25%         2.000000   420.500000      30.000000            30.950000
# 50%         3.000000   595.000000      51.000000            66.400000
# 75%         4.000000   851.000000      71.500000            88.000000
# max         5.000000  2314.000000      98.000000            99.800000
#
#        state_percentile_15  stu_teach_ratio  avg_score_15  avg_score_16  \
# count           341.000000       347.000000    341.000000    347.000000
# mean             58.249267        15.461671     57.004692     57.049856
# std              32.702630         5.725170     26.696450     27.968974
# ...

# %%
#extract the relevant variables

dff[['reduced_lunch','school_rating']].groupby(['school_rating']).describe().unstack()
# Out:
#                       school_rating
# reduced_lunch  count  0.0              43.000000
#                       1.0              40.000000
#                       2.0              44.000000
#                       3.0              56.000000
#                       4.0              86.000000
#                       5.0              78.000000
#                mean   0.0              83.581395
#                       1.0              74.950000
#                       2.0              64.272727
#                       3.0              50.285714
#                       4.0              41.000000
#                       5.0              21.602564
#                std    0.0               8.813498
#                       1.0              11.644191
#                       2.0              11.956051
#                       3.0              13.550866
#                       4.0              16.681092
#                       5.0              17.651268
# ...

# %%
#examine the correlation between relevant variables

dff[['reduced_lunch','school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %% [markdown]
# Exercise 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dff= pd.read_csv('mtcars.csv')
dff
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
dff.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
dff.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
dff.sample(10)
# Out:
#              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 13     Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# 11      Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 22     AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 17        Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
#
#     carb
# 13     3
# 11     3
# 25     1
# 1      4
# 22     2
# 20     1
# 3      1
# 29     6
# 17     1
# 0      4

# %%
dff.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
include =['object','float','int']
dff.describe(include=include)
dff.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
dff.hp.value_counts()
dff.hp.hist(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# variable analysis

# %%
#check missing values and outliers


dff.plot.scatter('mpg', 'hp')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='hp'>

# %%
#checking missing values

import missingno as msno
msno.bar(dff)
msno.heatmap(dff)

np.mean(dff['hp'])

from scipy import stats
stats.mode(dff['model'])

dffcopy['hp'].fillna()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7180/399949030.py in <module>
#       1 #checking missing values
#       2
# ----> 3 import missingno as msno
#       4 msno.bar(dff)
#       5 msno.heatmap(dff)
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# exercise 4

# %%
#finf missing values and outliers
import numpy as  np
import pandas as pd

# %%
df = pd.read_csv('mtcars.csv')

# %%
df.hp
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
df.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7180/3951303477.py in <module>
# ----> 1 df.data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
df['hp']
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
df1 = pd.df(np=hp.c_[df['hp'],  df['']], columns= df['new one'])

# %% [markdown]
# # exercise 5
#
#
# BOSTON DATASET FROM SCIKIT-LEARN LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets
boston = datasets.load_boston()

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
z = boston.DESCR

# %%
z
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
s = boston.feature_names

# %%
s
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
boston.data.shape
# Out:
# (506, 13)

# %%
#converting data from nd-array to dataframe

# %%
boston.data.dtype
# Out:
# dtype('float64')

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
data = pd.DataFrame(boston.data)
data.columns = boston.feature_names

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#Adding 'price' column to the dataset

# %%
boston.target.shape
# Out:
# (506,)

# %%
data['Price'] =  boston.target

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
#Description pf boston dataset
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# spiliting data into testing and training set

# %%
#input data
x = boston.data

#output data
y = boston.target

#from sklearn.cross_validation import train_test_split

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.2, random_state =0)

print('xtrain shape:', xtrain.shape)
print('xtest  shape:', xtest.shape)
print('ytrain shape:', ytrain.shape)
print('ytest shape:',  ytest.shape)
# Out:
# xtrain shape: (404, 13)
# xtest  shape: (102, 13)
# ytrain shape: (404,)
# ytest shape: (102,)

# %%
#applying linear regression model to the dataset and predicting the prices

#fitting multi linear regration model to training model

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)


#predicting the test set results

y_pred = regressor.predict(xtest)

# %%
y_pred
# Out:
# array([24.88963777, 23.72141085, 29.36499868, 12.12238621, 21.44382254,
#        19.2834443 , 20.49647539, 21.36099298, 18.8967118 , 19.9280658 ,
#         5.12703513, 16.3867396 , 17.07776485,  5.59375659, 39.99636726,
#        32.49654668, 22.45798809, 36.85192327, 30.86401089, 23.15140009,
#        24.77495789, 24.67187756, 20.59543752, 30.35369168, 22.41940736,
#        10.23266565, 17.64816865, 18.27419652, 35.53362541, 20.96084724,
#        18.30413012, 17.79262072, 19.96561663, 24.06127231, 29.10204874,
#        19.27774123, 11.15536648, 24.57560579, 17.5862644 , 15.49454112,
#        26.20577527, 20.86304693, 22.31460516, 15.60710156, 23.00363104,
#        25.17247952, 20.11459464, 22.90256276, 10.0380507 , 24.28515123,
#        20.94127711, 17.35258791, 24.52235405, 29.95143046, 13.42695877,
#        21.72673066, 20.7897053 , 15.49668805, 13.98982601, 22.18377874,
#        17.73047814, 21.58869165, 32.90522136, 31.11235671, 17.73252635,
# ...

# %%
#plotting Scatter graph to show the prediction results

# %%
#plotting Scatter graph to show the prediction
#results - 'ytrue' value vs 'y_pred' value

plt.scatter(ytest, y_pred, c = 'orange')
plt.xlabel("price : in $1000's")
plt.ylabel('predicted value')
plt.title('True value vs predicted value : Linear Regration')
plt.show()

# %%
#Result of Linear Regration

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, y_pred)
print("Mean Square Error:", mse)
# Out:
# Mean Square Error: 33.448979997676346

# %% [markdown]
# As per the result, our model is only 66.55% accurate. So, the model is not very good for housing prices🤷‍♂️🤷‍♀️🤷‍♂️🤷‍♀️🤷‍♂️🤷‍♀️

# %% [markdown]
# #

# %% [markdown]
# # exercise 6

# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

# %matplotlib inline

# %%
data = pd.read_csv('Advertising.csv', index_col=0)

data.head()
data.columns = ['TV','Radio','Newspaper','Sales']

# %%
data.shape
# Out:
# (200, 4)

# %%
fig,axs = plt.subplots(1,3,sharey = True)
data.plot(kind = 'scatter', x = 'TV', y = 'Sales', ax = axs[0], figsize = (16,8))
data.plot(kind="scatter", x ='Radio', y ='Sales',  ax = axs[1])
data.plot(kind='scatter', x= 'Newspaper', y ='Sales', ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Sales'>

# %%
feature_cols = ['TV']
x = data[feature_cols]
y = data.Sales

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# 7.0325935491276965
# [0.04753664]

# %%
7.032594+0.047537*50
# Out:
# 9.409444

# %%
X_new = pd.DataFrame({'TV':[50]})
X_new.head()
# Out:
#    TV
# 0  50

# %%
lm.predict(X_new)
# Out:
# array([9.40942557])

# %%
X_new = pd.DataFrame({'TV': [data.TV.min(), data.TV.max()]})
X_new.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
lm.predict(X_new)
# Out:
# array([ 7.0658692 , 21.12245377])

# %%
X_new = pd.DataFrame({'TV':[data.TV.min(),data.TV.max()]})
X_new.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
preds = lm.predict(X_new)
preds
# Out:
# array([ 7.0658692 , 21.12245377])

# %%
data.plot(kind="scatter", x= 'TV', y ='Sales')
plt.plot(X_new, preds, c = 'red', linewidth = 2)

# %%
import statsmodels.formula.api as smf
lm = smf.ols(formula = "Sales ~ TV ", data = data).fit()

# %%
lm.conf_int()
# Out:
#                   0         1
# Intercept  6.129719  7.935468
# TV         0.042231  0.052843

# %%
lm.pvalues
# Out:
# Intercept    1.406300e-35
# TV           1.467390e-42
# dtype: float64

# %%
lm.rsquared
# Out:
# 0.611875050850071

# %%
feature_col = ['TV', 'Radio', 'Newspaper']
x = data[feature_cols]
y = data.Sales
from sklearn import model_selection
xtrain, xtest, ytrain, ytest = model_selection.train_test_split(x,y,test_size = 0.3, random_state = 42)

# %%
lm = LinearRegression()
lm.fit(x,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# 7.0325935491276965
# [0.04753664]

# %%
lm = LinearRegression()
lm.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)

predictions = lm.predict(xtest)
print(sqrt(mean_squared_error(ytest,predictions)))
# Out:
# 7.23945983075114
# [0.0464078]
# 2.995161304907236

# %%
lm = smf.ols(formula = 'Sales~TV + Radio +Newspaper', data = data).fit()
lm.conf_int()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 10 Mar 2022   Prob (F-statistic):           1.58e-96
# Time:                        10:12:04   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
lm = smf.ols(formula = "Sales ~ TV + Radio", data=data).fit()
lm.rsquared
# Out:
# 0.8971942610828957

# %%
lm = smf.ols(formula = "Sales ~ TV +Radio + Newspaper", data=data).fit()
lm.rsquared
# Out:
# 0.8972106381789522

# %%
import numpy as np
np.random.seed(12345)

nums = np.random.rand(len(data))
mask_large = nums > 0.5

data["Size"] = 'small'
data.loc[mask_large, 'Size'] = "large"
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size
# 1  230.1   37.8       69.2   22.1  large
# 2   44.5   39.3       45.1   10.4  small
# 3   17.2   45.9       69.3    9.3  small
# 4  151.5   41.3       58.5   18.5  small
# 5  180.8   10.8       58.4   12.9  large

# %%
data['IsLarge'] = data.Size.map({'small': 0,'large':1})
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size  IsLarge
# 1  230.1   37.8       69.2   22.1  large        1
# 2   44.5   39.3       45.1   10.4  small        0
# 3   17.2   45.9       69.3    9.3  small        0
# 4  151.5   41.3       58.5   18.5  small        0
# 5  180.8   10.8       58.4   12.9  large        1

# %%
feature_cols = ['TV', 'Radio', 'Newspaper','IsLarge']
x = data[feature_cols]
y = data.Sales

lm = LinearRegression()
lm.fit(x,y)

zip(feature_cols, lm.coef_)

# %%
np.random.seed(123456)

nums = np.random.rand(len(data))
mask_suburban = (nums > 0.33) & (nums < 0.66)
mask_urban = nums > 0.66
data['Area'] = 'rural'
data.loc[mask_suburban, 'Area'] = "suburban"
data.loc[mask_urban, 'Area'] = 'urban'
data.head()
# Out:
#       TV  Radio  Newspaper  Sales   Size  IsLarge      Area
# 1  230.1   37.8       69.2   22.1  large        1     rural
# 2   44.5   39.3       45.1   10.4  small        0     urban
# 3   17.2   45.9       69.3    9.3  small        0     rural
# 4  151.5   41.3       58.5   18.5  small        0     urban
# 5  180.8   10.8       58.4   12.9  large        1  suburban

# %%
feature_cols = ['TV', 'Radio', 'Newspaper', 'IsLarge','Area_suburban','Area_urban']
x = data[feature_cols]
y = data.sales

lm = LinearRegression()
lm.fit(x,y)
print(feature_cols, lm.coef_)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7600/2389696736.py in <module>
#       1 feature_cols = ['TV', 'Radio', 'Newspaper', 'IsLarge','Area_suburban','Area_urban']
# ----> 2 x = data[feature_cols]
#       3 y = data.sales
#       4
#       5 lm = LinearRegression()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %% [markdown]
# # exercise 7

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("bigmart_train.csv")

# %%
train.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
train.shape
# Out:
# (8523, 12)

# %%
train.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
train['Outlet_Establishment_Year'].unique()
# Out:
# array([1999, 2009, 1998, 1987, 1985, 2002, 2007, 1997, 2004], dtype=int64)

# %%
train['Outlet_Age']= 2018-train['Outlet_Establishment_Year']
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# # exercise 7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
animals = pd.read_csv('horse.csv')

# %%
animals
# Out:
#     surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0        no  adult           530101         38.5   66.0              28.0
# 1       yes  adult           534817         39.2   88.0              20.0
# 2        no  adult           530334         38.3   40.0              24.0
# 3       yes  young          5290409         39.1  164.0              84.0
# 4        no  adult           530255         37.3  104.0              35.0
# ..      ...    ...              ...          ...    ...               ...
# 294     yes  adult           533886          NaN  120.0              70.0
# 295      no  adult           527702         37.2   72.0              24.0
# 296     yes  adult           529386         37.5   72.0              30.0
# 297     yes  adult           530612         36.5  100.0              24.0
# 298     yes  adult           534618         37.2   40.0              20.0
#
#     temp_of_extremities peripheral_pulse mucous_membrane  \
# ...

# %%
target = animals['outcome']

# %%
target
# Out:
# 0            died
# 1      euthanized
# 2           lived
# 3            died
# 4            died
#           ...
# 294    euthanized
# 295    euthanized
# 296          died
# 297         lived
# 298    euthanized
# Name: outcome, Length: 299, dtype: object

# %%
animals = animals.drop(['outcome'], axis=1)

# %%
catrgory_variables = ['surgery', 'age' 'temp_of_extremities', 'peripheral_pulse',
                      'mucous_membrane', 'capillary_refill_time', 'pain', 'peristalsis',
                      'abdominal_distention', 'nasogastric_tube', 'nasogastric_reflux',
                      'rectal_exam_feces', 'abdomen','abdomo_appearance','surgical_lesion',
                      'cp_data']
for category in category_variables:
    animals[category]= pd.get_dummies(animals[category])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11984/88469655.py in <module>
#       5                       'cp_data']
#       6 for category in category_variables:
# ----> 7     animals[category]= pd.get_dummies(animals[category])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
# -> 3602             self._set_item_frame_value(key, value)
#    3603         elif (
#    3604             is_list_like(value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3727             len_cols = 1 if is_scalar(cols) else len(cols)
#    3728             if len_cols != len(value.columns):
# ...

# %%
animals._get_numeric_data().columns
# Out:
# Index(['hospital_number', 'rectal_temp', 'pulse', 'respiratory_rate',
#        'nasogastric_reflux_ph', 'packed_cell_volume', 'total_protein',
#        'abdomo_protein', 'lesion_1', 'lesion_2', 'lesion_3'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

y = animals.values,target.values
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11984/4286863684.py in <module>
#       4 y = animals.values,target.values
#       5 label_encoder = LabelEncoder()
# ----> 6 y = label_encoder.fit_transform(y)
#       7 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=1)
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     114         y : array-like of shape (n_samples,)
#     115         """
# --> 116         y = column_or_1d(y, warn=True)
#     117         self.classes_, y = _unique(y, return_inverse=True)
#     118         return y
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
print(X_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11984/1687983409.py in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
# ----> 2 print(X_train.shape)
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.preprocessing import Imputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11984/2249281258.py in <module>
# ----> 1 from sklearn.preprocessing import Imputer
#
# ImportError: cannot import name 'Imputer' from 'sklearn.preprocessing' (C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %% [markdown]
# # exercise 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
loan = pd.read_csv('loan_borowwer_data.csv')

# %%
loan.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
loan.tail()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 9573       12.180755  10.39   672       10474.000000     215372        82.1
# 9574       11.141862   0.21   722        4380.000000        184         1.1
# 9575       10.596635  13.09   687        3450.041667      10036        82.9
# 9576       10.819778  19.18   692        1800.000000          0         3.2
# 9577       11.264464  16.28   732        4740.000000      37879        57.0
#
#       inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# 9573               2            0        0               1
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loan['purpose'].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %%
loan.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loan.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(10,6))
loan[loan['credit.policy']==1]['fico'].hist(alpha=0.5, color='blue', bins=30,label='credit.policy=1')
loan[loan['credit.policy']==0]['fico'].hist(alpha=0.5, color='red', bins=30, label='credit.policy=0')
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %%
plt.figure(figsize=(10,6))
loan[loan['not.fully.paid']==1]['fico'].hist(alpha=0.5,color='blue',bins=30, label='not.fully.paid=1')
loan[loan['not.fully.paid']==0]['fico'].hist(alpha=0.5, color='red', bins=30, label='not.fully.paid=0')
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %%
df = loan.copy()

# %%
df
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
df.rename(columns={'not.fully.paid': 'not_fully_paid'},inplace =True)
df
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
labels = 'FULLY PAID','NOT FULLY PAID'
sizes = [df.not_fully_paid[df['not_fully_paid']==0].count(), df.not_fully_paid[df['not_fully_paid']==1].count()]
explode = (0,0.1)
fig1, ax1 = plt.subplots(figsize=(10,8))
ax1.pie(sizes, explode=explode, labels = labels, autopct ='%1.1f%%',
        shadow = True, startangle = 90)
ax1.axis('equal')
plt.title('Proportion of customer with fully paid and fully not paid', size = 20)
plt.show()

# %%
labels = df['purpose'].astype('category').cat.categories.tolist()
counts = df['purpose'].value_counts()
sizes = [counts[var_cat] for var_cat in labels]
fig1, ax1 = plt.subplots()
explode = (0.1,0,0,0,0,0,0)
ax1.pie(sizes, labels=labels, autopct = '%1.1f%%', shadow=True)
ax1.axis('equal')
plt.show()

# %%
loan.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# # Create a countplot using seaborn showing the counts of loans by purpose, with the hue defined by not.fully.paid.

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='purpose', hue ='not.fully.paid',data = loan, palette='Set1')
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %%
#without palette:

plt.figure(figsize=(11,7))
sns.countplot(x='purpose', hue='not.fully.paid', data=loan)
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %% [markdown]
# Create a countplot using seaborn showing the counts of loans by purpose, with the hue defined by not.fully.paid.

# %% [markdown]
# # Setting Up the Data

# %% [markdown]
# Create a list of elements, containing the string "purpose." Call this list 'cat_feats'

# %%
cat_feats = ['purpose']

# %%
cat_feats
# Out:
# ['purpose']

# %% [markdown]
# # Now use pd.get_dummies(loans,columns=cat_feats,drop_first=True) to create a fixed larger data frame that has new feature columns with dummy variables. Set this data frame as final_data

# %%
import numpy as np
import pandas as pd
import matplotlib.plt as plot
from sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8728/4089203772.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib.plt as plot
#
# ModuleNotFoundError: No module named 'matplotlib.plt'

# %%
df = read_csv('salaryGender.csv')
